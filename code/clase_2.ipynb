# %%
import sys
print("Hola, mundo del Álgebra Lineal")
print(f"Tu versión de Python es {sys.version}")
# Out:
# Hola, mundo del Álgebra Lineal
# Tu versión de Python es 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
